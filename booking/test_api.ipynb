# %%
import asyncio
import aiohttp

# %%
async def fetch(type:str, i:int):
    async with aiohttp.ClientSession() as session:
        async with session.get(f'http://127.0.0.1:8000/{type}/{i}') as response:
            print('Завершен fetch')

# %%
# await fetch('sync')
await asyncio.gather(*[fetch('async', i) for i in range(1, 100)])
# Out:
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# Завершен fetch
# ...
